# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import cv2
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras.utils import np_utils
import sklearn.metrics as metrics
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
train = pd.read_csv("data_diac_train.csv",delimiter = ',')
test = pd.read_csv("data_diac_test.csv", delimiter = ',')

# %%
HEIGHT = 16
WIDTH = 16

# %%
train_x = train.iloc[:,1:]
train_y = train.iloc[:,0]
del train

test_x = test.iloc[:,1:]
test_y = test.iloc[:,0]
del test

# %%
print(train_x.shape,train_y.shape,test_x.shape,test_y.shape)
# Out:
# (1275, 256) (1275,) (318, 256) (318,)

# %%
def rotate(image):
    image = image.reshape([HEIGHT, WIDTH])
    # image = np.fliplr(image)
    # image = np.rot90(image)
    return image

# %%
train_x = np.asarray(train_x)
train_x = np.apply_along_axis(rotate, 1, train_x)
print ("train_x:",train_x.shape)

test_x = np.asarray(test_x)
test_x = np.apply_along_axis(rotate, 1, test_x)
print ("test_x:",test_x.shape)
# Out:
# train_x: (1275, 16, 16)
# test_x: (318, 16, 16)

# %%
train_x = train_x.astype('float32')
train_x /= 255
test_x = test_x.astype('float32')
test_x /= 255

# %%
for i in range(100, 109):
    plt.subplot(330 + (i+1))
    plt.imshow(train_x[i], cmap=plt.get_cmap('gray'))
    plt.title(train_y[i])

# %%
num_classes = train_y.nunique()

# %%
train_y = np_utils.to_categorical(train_y,num_classes)
test_y = np_utils.to_categorical(test_y,num_classes)
print("train_y: ", train_y.shape)
print("test_y: ", test_y.shape)
# Out:
# train_y:  (1275, 9)
# test_y:  (318, 9)

# %%
train_x = train_x.reshape(-1, HEIGHT, WIDTH, 1)
test_x = test_x.reshape(-1, HEIGHT, WIDTH, 1)

# %%
train_x, val_x, train_y, val_y = train_test_split(train_x, train_y, test_size= 0.1, random_state=7)

# %%
model = Sequential()

model.add(Conv2D(filters=128, kernel_size=(5,5), padding = 'same', activation='relu',\
                 input_shape=(HEIGHT, WIDTH,1)))
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2)))
model.add(Conv2D(filters=64, kernel_size=(3,3) , padding = 'same', activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Flatten())
model.add(Dense(units=128, activation='relu'))
model.add(Dropout(.5))
model.add(Dense(units=num_classes, activation='softmax'))

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_2 (Conv2D)           (None, 16, 16, 128)       3328
#
#  max_pooling2d_2 (MaxPooling  (None, 8, 8, 128)        0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 8, 8, 64)          73792
#
#  max_pooling2d_3 (MaxPooling  (None, 4, 4, 64)         0
#  2D)
#
#  flatten_1 (Flatten)         (None, 1024)              0
#
#  dense_2 (Dense)             (None, 128)               131200
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_3 (Dense)             (None, 9)                 1161
#
# =================================================================
# Total params: 209,481
# Trainable params: 209,481
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
history = model.fit(train_x, train_y, epochs=25, batch_size=52, verbose=1, \
                    validation_data=(val_x, val_y))
# Out:
# Epoch 1/25
# 23/23 [==============================] - 4s 21ms/step - loss: 1.7142 - accuracy: 0.4220 - val_loss: 0.6506 - val_accuracy: 0.8672
# Epoch 2/25
# 23/23 [==============================] - 0s 9ms/step - loss: 0.6613 - accuracy: 0.7881 - val_loss: 0.2156 - val_accuracy: 0.9531
# Epoch 3/25
# 23/23 [==============================] - 0s 8ms/step - loss: 0.4359 - accuracy: 0.8666 - val_loss: 0.1514 - val_accuracy: 0.9609
# Epoch 4/25
# 23/23 [==============================] - 0s 7ms/step - loss: 0.2817 - accuracy: 0.9215 - val_loss: 0.0887 - val_accuracy: 0.9844
# Epoch 5/25
# 23/23 [==============================] - 0s 7ms/step - loss: 0.2105 - accuracy: 0.9329 - val_loss: 0.0606 - val_accuracy: 0.9922
# Epoch 6/25
# 23/23 [==============================] - 0s 6ms/step - loss: 0.2173 - accuracy: 0.9372 - val_loss: 0.0347 - val_accuracy: 0.9922
# Epoch 7/25
# 23/23 [==============================] - 0s 6ms/step - loss: 0.1206 - accuracy: 0.9660 - val_loss: 0.0276 - val_accuracy: 0.9922
# Epoch 8/25
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0797 - accuracy: 0.9738 - val_loss: 0.0121 - val_accuracy: 1.0000
# Epoch 9/25
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0773 - accuracy: 0.9808 - val_loss: 0.0249 - val_accuracy: 0.9844
# Epoch 10/25
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0769 - accuracy: 0.9826 - val_loss: 0.0216 - val_accuracy: 0.9922
# Epoch 11/25
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0691 - accuracy: 0.9773 - val_loss: 0.0047 - val_accuracy: 1.0000
# Epoch 12/25
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0602 - accuracy: 0.9808 - val_loss: 0.0078 - val_accuracy: 1.0000
# Epoch 13/25
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0464 - accuracy: 0.9878 - val_loss: 0.0140 - val_accuracy: 0.9922
# Epoch 14/25
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0592 - accuracy: 0.9843 - val_loss: 0.0169 - val_accuracy: 0.9922
# Epoch 15/25
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0452 - accuracy: 0.9826 - val_loss: 0.0122 - val_accuracy: 0.9922
# Epoch 16/25
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0467 - accuracy: 0.9852 - val_loss: 0.0051 - val_accuracy: 1.0000
# Epoch 17/25
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0313 - accuracy: 0.9913 - val_loss: 0.0327 - val_accuracy: 0.9922
# Epoch 18/25
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0614 - accuracy: 0.9817 - val_loss: 0.0204 - val_accuracy: 0.9922
# Epoch 19/25
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0570 - accuracy: 0.9808 - val_loss: 0.0063 - val_accuracy: 1.0000
# Epoch 20/25
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0217 - accuracy: 0.9956 - val_loss: 0.0268 - val_accuracy: 0.9922
# Epoch 21/25
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0229 - accuracy: 0.9939 - val_loss: 0.0120 - val_accuracy: 0.9922
# Epoch 22/25
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0343 - accuracy: 0.9887 - val_loss: 0.0162 - val_accuracy: 0.9922
# Epoch 23/25
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0261 - accuracy: 0.9939 - val_loss: 0.0058 - val_accuracy: 1.0000
# Epoch 24/25
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0223 - accuracy: 0.9939 - val_loss: 0.0062 - val_accuracy: 1.0000
# Epoch 25/25
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0192 - accuracy: 0.9948 - val_loss: 0.0132 - val_accuracy: 0.9922

# %%
def plotgraph(epochs, acc, val_acc):
    plt.plot(epochs, acc, 'b')
    plt.plot(epochs, val_acc, 'r')
    plt.title('Model accuracy')
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Val'], loc='upper left')
    plt.show()

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1,len(acc)+1)

# %%
plotgraph(epochs, acc, val_acc)

# %%
plotgraph(epochs, loss, val_loss)

# %%
score = model.evaluate(test_x, test_y, verbose=0)
print("Test loss:", score[0])
print("Test accuracy:", score[1])
# Out:
# Test loss: 0.030864965170621872
# Test accuracy: 0.9937106966972351

# %%
y_pred = model.predict(test_x)
y_pred = (y_pred > 0.5)
# Out:
# 10/10 [==============================] - 0s 2ms/step

# %%
cm = metrics.confusion_matrix(test_y.argmax(axis=1), y_pred.argmax(axis=1))

# %%
cm
# Out:
# array([[35,  0,  0,  0,  0,  0,  0,  0,  0],
#        [ 0, 41,  0,  0,  0,  0,  0,  0,  0],
#        [ 0,  0, 39,  0,  0,  0,  0,  0,  0],
#        [ 0,  0,  0, 40,  0,  0,  0,  0,  0],
#        [ 0,  0,  0,  0, 31,  0,  0,  1,  0],
#        [ 0,  0,  0,  0,  0, 28,  0,  0,  0],
#        [ 0,  0,  0,  0,  0,  0, 35,  0,  0],
#        [ 0,  0,  0,  0,  0,  1,  0, 30,  0],
#        [ 0,  0,  0,  0,  0,  0,  0,  0, 37]])

# %%
model.save('../model_diac', save_format="h5")
