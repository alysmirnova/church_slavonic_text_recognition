# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import cv2
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras.utils import np_utils
import sklearn.metrics as metrics
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
train = pd.read_csv("data_train.csv",delimiter = ',')
test = pd.read_csv("data_test.csv", delimiter = ',')

# %%
HEIGHT = 28
WIDTH = 28

# %%
train_x = train.iloc[:,1:]
train_y = train.iloc[:,0]
del train

test_x = test.iloc[:,1:]
test_y = test.iloc[:,0]
del test

# %%
print(train_x.shape,train_y.shape,test_x.shape,test_y.shape)
# Out:
# (7560, 784) (7560,) (1889, 784) (1889,)

# %%
def rotate(image):
    image = image.reshape([HEIGHT, WIDTH])
    # image = np.fliplr(image)
    # image = np.rot90(image)
    return image

# %%
train_x = np.asarray(train_x)
train_x = np.apply_along_axis(rotate, 1, train_x)
print ("train_x:",train_x.shape)

test_x = np.asarray(test_x)
test_x = np.apply_along_axis(rotate, 1, test_x)
print ("test_x:",test_x.shape)
# Out:
# train_x: (7560, 28, 28)
# test_x: (1889, 28, 28)

# %%
train_x = train_x.astype('float32')
train_x /= 255
test_x = test_x.astype('float32')
test_x /= 255

# %%
for i in range(300, 309):
    plt.subplot(330 + (i+1))
    plt.imshow(train_x[i], cmap=plt.get_cmap('gray'))
    # plt.title(train_y[i])

# %%
num_classes = train_y.nunique()

# %%
train_y = np_utils.to_categorical(train_y,num_classes)
test_y = np_utils.to_categorical(test_y,num_classes)
print("train_y: ", train_y.shape)
print("test_y: ", test_y.shape)
# Out:
# train_y:  (7560, 43)
# test_y:  (1889, 43)

# %%
train_x = train_x.reshape(-1, HEIGHT, WIDTH, 1)
test_x = test_x.reshape(-1, HEIGHT, WIDTH, 1)

# %%
train_x, val_x, train_y, val_y = train_test_split(train_x, train_y, test_size= 0.1, random_state=7)

# %%
model = Sequential()

model.add(Conv2D(filters=128, kernel_size=(5,5), padding = 'same', activation='relu',\
                 input_shape=(HEIGHT, WIDTH,1)))
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2)))
model.add(Conv2D(filters=64, kernel_size=(3,3) , padding = 'same', activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Flatten())
model.add(Dense(units=128, activation='relu'))
model.add(Dropout(.5))
model.add(Dense(units=num_classes, activation='softmax'))

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_2 (Conv2D)           (None, 28, 28, 128)       3328
#
#  max_pooling2d_2 (MaxPooling  (None, 14, 14, 128)      0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 14, 14, 64)        73792
#
#  max_pooling2d_3 (MaxPooling  (None, 7, 7, 64)         0
#  2D)
#
#  flatten_1 (Flatten)         (None, 3136)              0
#
#  dense_2 (Dense)             (None, 128)               401536
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_3 (Dense)             (None, 43)                5547
#
# =================================================================
# Total params: 484,203
# Trainable params: 484,203
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
history = model.fit(train_x, train_y, epochs=40, batch_size=72, verbose=1, \
                    validation_data=(val_x, val_y))
# Out:
# Epoch 1/40
# 95/95 [==============================] - 3s 13ms/step - loss: 1.8413 - accuracy: 0.5071 - val_loss: 0.2497 - val_accuracy: 0.9405
# Epoch 2/40
# 95/95 [==============================] - 1s 9ms/step - loss: 0.4533 - accuracy: 0.8732 - val_loss: 0.1159 - val_accuracy: 0.9709
# Epoch 3/40
# 95/95 [==============================] - 1s 7ms/step - loss: 0.2777 - accuracy: 0.9171 - val_loss: 0.0777 - val_accuracy: 0.9828
# Epoch 4/40
# 95/95 [==============================] - 1s 7ms/step - loss: 0.1970 - accuracy: 0.9442 - val_loss: 0.0717 - val_accuracy: 0.9841
# Epoch 5/40
# 95/95 [==============================] - 1s 7ms/step - loss: 0.1575 - accuracy: 0.9537 - val_loss: 0.0579 - val_accuracy: 0.9881
# Epoch 6/40
# 95/95 [==============================] - 1s 7ms/step - loss: 0.1381 - accuracy: 0.9596 - val_loss: 0.0648 - val_accuracy: 0.9828
# Epoch 7/40
# 95/95 [==============================] - 1s 7ms/step - loss: 0.1186 - accuracy: 0.9609 - val_loss: 0.0620 - val_accuracy: 0.9881
# Epoch 8/40
# 95/95 [==============================] - 1s 7ms/step - loss: 0.0967 - accuracy: 0.9697 - val_loss: 0.0634 - val_accuracy: 0.9881
# Epoch 9/40
# 95/95 [==============================] - 1s 7ms/step - loss: 0.0852 - accuracy: 0.9724 - val_loss: 0.0621 - val_accuracy: 0.9868
# Epoch 10/40
# 95/95 [==============================] - 1s 7ms/step - loss: 0.0764 - accuracy: 0.9787 - val_loss: 0.0729 - val_accuracy: 0.9868
# Epoch 11/40
# 95/95 [==============================] - 1s 7ms/step - loss: 0.0825 - accuracy: 0.9752 - val_loss: 0.0599 - val_accuracy: 0.9868
# Epoch 12/40
# 95/95 [==============================] - 1s 7ms/step - loss: 0.0671 - accuracy: 0.9793 - val_loss: 0.0523 - val_accuracy: 0.9921
# Epoch 13/40
# 95/95 [==============================] - 1s 7ms/step - loss: 0.0559 - accuracy: 0.9809 - val_loss: 0.0589 - val_accuracy: 0.9881
# Epoch 14/40
# 95/95 [==============================] - 1s 7ms/step - loss: 0.0646 - accuracy: 0.9800 - val_loss: 0.0775 - val_accuracy: 0.9854
# Epoch 15/40
# 95/95 [==============================] - 1s 7ms/step - loss: 0.0564 - accuracy: 0.9816 - val_loss: 0.0724 - val_accuracy: 0.9894
# Epoch 16/40
# 95/95 [==============================] - 1s 7ms/step - loss: 0.0500 - accuracy: 0.9835 - val_loss: 0.0640 - val_accuracy: 0.9881
# Epoch 17/40
# 95/95 [==============================] - 1s 7ms/step - loss: 0.0488 - accuracy: 0.9834 - val_loss: 0.0577 - val_accuracy: 0.9921
# Epoch 18/40
# 95/95 [==============================] - 1s 9ms/step - loss: 0.0494 - accuracy: 0.9834 - val_loss: 0.0741 - val_accuracy: 0.9854
# Epoch 19/40
# 95/95 [==============================] - 1s 9ms/step - loss: 0.0446 - accuracy: 0.9850 - val_loss: 0.0666 - val_accuracy: 0.9868
# Epoch 20/40
# 95/95 [==============================] - 1s 9ms/step - loss: 0.0495 - accuracy: 0.9846 - val_loss: 0.0497 - val_accuracy: 0.9881
# Epoch 21/40
# 95/95 [==============================] - 1s 7ms/step - loss: 0.0385 - accuracy: 0.9863 - val_loss: 0.0573 - val_accuracy: 0.9881
# Epoch 22/40
# 95/95 [==============================] - 1s 7ms/step - loss: 0.0364 - accuracy: 0.9879 - val_loss: 0.0590 - val_accuracy: 0.9894
# Epoch 23/40
# 95/95 [==============================] - 1s 7ms/step - loss: 0.0328 - accuracy: 0.9881 - val_loss: 0.0573 - val_accuracy: 0.9894
# Epoch 24/40
# 95/95 [==============================] - 1s 7ms/step - loss: 0.0390 - accuracy: 0.9877 - val_loss: 0.0375 - val_accuracy: 0.9894
# Epoch 25/40
# 95/95 [==============================] - 1s 7ms/step - loss: 0.0367 - accuracy: 0.9890 - val_loss: 0.0458 - val_accuracy: 0.9894
# Epoch 26/40
# 95/95 [==============================] - 1s 7ms/step - loss: 0.0352 - accuracy: 0.9878 - val_loss: 0.0640 - val_accuracy: 0.9868
# Epoch 27/40
# 95/95 [==============================] - 1s 7ms/step - loss: 0.0362 - accuracy: 0.9879 - val_loss: 0.0522 - val_accuracy: 0.9894
# Epoch 28/40
# 95/95 [==============================] - 1s 7ms/step - loss: 0.0326 - accuracy: 0.9885 - val_loss: 0.0510 - val_accuracy: 0.9894
# Epoch 29/40
# 95/95 [==============================] - 1s 7ms/step - loss: 0.0345 - accuracy: 0.9884 - val_loss: 0.0430 - val_accuracy: 0.9894
# Epoch 30/40
# 95/95 [==============================] - 1s 7ms/step - loss: 0.0309 - accuracy: 0.9879 - val_loss: 0.0569 - val_accuracy: 0.9894
# Epoch 31/40
# 95/95 [==============================] - 1s 7ms/step - loss: 0.0263 - accuracy: 0.9907 - val_loss: 0.0613 - val_accuracy: 0.9907
# Epoch 32/40
# 95/95 [==============================] - 1s 7ms/step - loss: 0.0286 - accuracy: 0.9888 - val_loss: 0.0680 - val_accuracy: 0.9868
# Epoch 33/40
# 95/95 [==============================] - 1s 7ms/step - loss: 0.0307 - accuracy: 0.9899 - val_loss: 0.0373 - val_accuracy: 0.9921
# Epoch 34/40
# 95/95 [==============================] - 1s 7ms/step - loss: 0.0254 - accuracy: 0.9922 - val_loss: 0.0678 - val_accuracy: 0.9881
# Epoch 35/40
# 95/95 [==============================] - 1s 8ms/step - loss: 0.0293 - accuracy: 0.9891 - val_loss: 0.0568 - val_accuracy: 0.9881
# Epoch 36/40
# 95/95 [==============================] - 1s 9ms/step - loss: 0.0291 - accuracy: 0.9894 - val_loss: 0.0503 - val_accuracy: 0.9921
# Epoch 37/40
# 95/95 [==============================] - 1s 8ms/step - loss: 0.0223 - accuracy: 0.9913 - val_loss: 0.0522 - val_accuracy: 0.9907
# Epoch 38/40
# 95/95 [==============================] - 1s 8ms/step - loss: 0.0305 - accuracy: 0.9897 - val_loss: 0.0493 - val_accuracy: 0.9881
# Epoch 39/40
# 95/95 [==============================] - 1s 7ms/step - loss: 0.0322 - accuracy: 0.9902 - val_loss: 0.0385 - val_accuracy: 0.9907
# Epoch 40/40
# 95/95 [==============================] - 1s 7ms/step - loss: 0.0252 - accuracy: 0.9909 - val_loss: 0.0542 - val_accuracy: 0.9907

# %%
def plotgraph(epochs, acc, val_acc):
    # Plot training & validation accuracy values
    plt.plot(epochs, acc, 'b')
    plt.plot(epochs, val_acc, 'r')
    plt.title('Model accuracy')
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Val'], loc='upper left')
    plt.show()

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1,len(acc)+1)

# %%
plotgraph(epochs, acc, val_acc)

# %%
plotgraph(epochs, loss, val_loss)

# %%
score = model.evaluate(test_x, test_y, verbose=0)
print("Test loss:", score[0])
print("Test accuracy:", score[1])
# Out:
# Test loss: 0.040849026292562485
# Test accuracy: 0.9915298819541931

# %%
y_pred = model.predict(test_x)
y_pred = (y_pred > 0.5)
# Out:
# 60/60 [==============================] - 0s 2ms/step

# %%
cm = metrics.confusion_matrix(test_y.argmax(axis=1), y_pred.argmax(axis=1))

# %%
cm
# Out:
# array([[33,  0,  1, ...,  0,  0,  0],
#        [ 0, 39,  0, ...,  0,  0,  0],
#        [ 0,  0, 32, ...,  0,  0,  0],
#        ...,
#        [ 0,  0,  0, ..., 39,  0,  0],
#        [ 0,  0,  0, ...,  0, 37,  0],
#        [ 0,  0,  0, ...,  0,  0, 39]])

# %%
sum = 0
for i in range(cm.shape[0]):
  for j in range (cm.shape[1]):
      if i != j:
        sum += cm[i][j]
sum
# Out:
# 16

# %%
model.save('../model_letters', save_format="h5")
